# %%
stockret<-read.csv('ITvsBankingData.csv', header=TRUE)

# %% [markdown]
# http://www.bseindia.com/indices/IndexArchiveData.aspx?expandable=1

# %%
hist(stockret$rtbanx)
# Out:
# Plot with title "Histogram of stockret$rtbanx"

# %%
hist(stockret$rtit)
# Out:
# Plot with title "Histogram of stockret$rtit"

# %% [markdown]
# # Homework
# * Histogram of bankex

# %%
boxplot(stockret$rtbanx)
boxplot(stockret$rtit)
# Out:
# plot without title
# plot without title

# %%
# One sample (Large) two tail Test
t.test(stockret$rtbanx,mu=0)
# Out:
# 	One Sample t-test
#
# data:  stockret$rtbanx
# t = 1.8318, df = 66, p-value = 0.07149
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  -0.001396361  0.032444856
# sample estimates:
#  mean of x
# 0.01552425

# %% [markdown]
# https://surfstat.anu.edu.au/surfstat-home/tables/t.php

# %%
t.test(stockret$rtit,mu=0)
# Out:
# 	One Sample t-test
#
# data:  stockret$rtit
# t = 1.3621, df = 66, p-value = 0.1778
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  -0.004721119  0.024992287
# sample estimates:
#  mean of x
# 0.01013558

# %%
t.test(stockret$rtbanx,mu=0.05,alternative = "greater") # Ho : mu<=0.05 
                                                        # Ha : mu>0.05
# Out:
# 	One Sample t-test
#
# data:  stockret$rtbanx
# t = -4.068, df = 66, p-value = 0.9999
# alternative hypothesis: true mean is greater than 0.05
# 95 percent confidence interval:
#  0.001385884         Inf
# sample estimates:
#  mean of x
# 0.01552425

# %%
t.test(stockret$rtbanx,mu=0.05,alternative = "less") # Ho : mu>=0.05 
                                                        # Ha : mu<0.05
# Out:
# 	One Sample t-test
#
# data:  stockret$rtbanx
# t = -4.068, df = 66, p-value = 6.448e-05
# alternative hypothesis: true mean is less than 0.05
# 95 percent confidence interval:
#        -Inf 0.02966261
# sample estimates:
#  mean of x
# 0.01552425

# %%
var.test(stockret$rtbanx,stockret$rtit) #Ho sigma2bak =
# Out:
# 	F test to compare two variances
#
# data:  stockret$rtbanx and stockret$rtit
# F = 1.2971, num df = 66, denom df = 66, p-value = 0.2931
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.7972876 2.1103727
# sample estimates:
# ratio of variances
#           1.297141

# %%
t.test(stockret$rtbanx,stockret$rtit)
# Out:
# 	Welch Two Sample t-test
#
# data:  stockret$rtbanx and stockret$rtit
# t = 0.4778, df = 129.83, p-value = 0.6336
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.01692383  0.02770116
# sample estimates:
#  mean of x  mean of y
# 0.01552425 0.01013558

# %%
t.test(stockret$rtbanx,stockret$rtit,var="equal")
# Out:
# Error in !var.equal: invalid argument type
# Traceback:
#
# 1. t.test(stockret$rtbanx, stockret$rtit, var = "equal")
# 2. t.test.default(stockret$rtbanx, stockret$rtit, var = "equal")
